# %% [markdown]
# ## <p style="text-align:center" color="red"><span style="color:red">Data warehousing in Azure postgreSQL - part 2</span></p>

# %% [markdown]
# ### Connecting Postgres database created in Azure cloud ( `using SQL magic keyword` )

# %%
# %load_ext sql
# %sql postgresql://labriji:Prosper12345*@labriji.postgres.database.azure.com:5432/prosper
# Out:
# C:\Users\SAAD\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\SAAD\anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\SAAD\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# %sql select * from public.accepted_loans limit 10;
# Out:
#  * postgresql://labriji:***@labriji.postgres.database.azure.com:5432/prosper
# 10 rows affected.
# [(3600.0, ' 36 months', 'C', '10+ years', 123.03, 'C', 'C4', '10+ years', 'MORTGAGE', 55000.0, 'Not Verified', 0, 'debt_consolidation', 5.91, 1.0, 675.0, 679.0),
#  (24700.0, ' 36 months', 'C', '10+ years', 820.28, 'C', 'C1', '10+ years', 'MORTGAGE', 65000.0, 'Not Verified', 0, 'small_business', 16.06, 1.0, 715.0, 719.0),
#  (20000.0, ' 60 months', 'B', '10+ years', 432.66, 'B', 'B4', '10+ years', 'MORTGAGE', 63000.0, 'Not Verified', 0, 'home_improvement', 10.78, 1.0, 695.0, 699.0),
#  (10400.0, ' 60 months', 'F', '3 years', 289.91, 'F', 'F1', '3 years', 'MORTGAGE', 104433.0, 'Source Verified', 0, 'major_purchase', 25.37, 1.0, 695.0, 699.0),
#  (11950.0, ' 36 months', 'C', '4 years', 405.18, 'C', 'C3', '4 years', 'RENT', 34000.0, 'Source Verified', 0, 'debt_consolidation', 10.2, 1.0, 690.0, 694.0),
# ...

# %% [markdown]
# ### Loading the dataset (stored in Azure Postgres Cloud Database) as panda's Dataframe

# %%
accepted_loans_query_result = %sql select * from public.accepted_loans;
accepted_loans = accepted_loans_query_result.DataFrame()
accepted_loans.head(5)
# Out:
#  * postgresql://labriji:***@labriji.postgres.database.azure.com:5432/prosper
# 1344936 rows affected.
#    loan_amnt        term grade emp_length  installment grade.1 sub_grade  \
# 0     3600.0   36 months     C  10+ years       123.03       C        C4
# 1    24700.0   36 months     C  10+ years       820.28       C        C1
# 2    20000.0   60 months     B  10+ years       432.66       B        B4
# 3    10400.0   60 months     F    3 years       289.91       F        F1
# 4    11950.0   36 months     C    4 years       405.18       C        C3
#
#    emp_title home_ownership  annual_inc verification_status  loan_status  \
# 0  10+ years       MORTGAGE     55000.0        Not Verified            0
# 1  10+ years       MORTGAGE     65000.0        Not Verified            0
# 2  10+ years       MORTGAGE     63000.0        Not Verified            0
# 3    3 years       MORTGAGE    104433.0     Source Verified            0
# ...

# %% [markdown]
# > - 🙌 Notebook made by [@labriji_saad](https://github.com/labrijisaad)
# > - 🔗 Linledin [@labriji_saad](https://www.linkedin.com/in/labrijisaad/)
